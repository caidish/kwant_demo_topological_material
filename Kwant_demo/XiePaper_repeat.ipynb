# %%
import kwant
import kwant.continuum
import numpy as np
import matplotlib.pyplot as pyplot
import tinyarray
# %matplotlib inline
import scipy
from tqdm.notebook import tqdm,trange

# %%
hamiltonian = """
vf*(k_y*kron(sigma_0,sigma_x) - k_x*kron(sigma_0,sigma_y))+ (m0-m1*(k_x**2+k_y**2))*kron(sigma_z,sigma_z) 
+ Mz(x,y)*kron(sigma_0,sigma_z) 
+ Ud(x,y)*kron(sigma_x,sigma_0) + Ua(x,y)*kron(sigma_0,sigma_0)
+ Ug*kron((sigma_z + sigma_0)/2, sigma_0)
"""
# kinetic term + SOC term 
# + magnetic term
# + random SIA term + random diagonal term
# + gate voltage
a = 1
r = 30
W = 32
L = 32
cell_size=4
num_cell = W/cell_size
M_model = (np.sqrt(5)-1)/2*5

def rand_bin_array(num_of_true,N):
    N = int(N)
    arr = np.zeros(N*N)
    arr[:num_of_true]  = 1
    np.random.shuffle(arr)
    return np.reshape(arr,[N,N])
def U_father(x,y,strength,matrix):
    return strength/2*matrix[int(x),int(y)]

def Mz_father(x,y,cell_array,cell_size):
    m = int(x//cell_size)
    n = int(y//cell_size)
    if cell_array[m,n]:
        return M_model
    else:
        return -M_model

# %%
# fermi surface dependent
template = kwant.continuum.discretize(hamiltonian,grid = a)
lat = template.lattice
def circle(site):
    x,y = site.pos
    return (x**2 + y**2 <= r**2)
def rect(site):
    x,y= site.pos
    return (0 <= y <W and 0 <=x <L)
syst = kwant.Builder()
syst.fill(template,rect,(0,0))
syst.eradicate_dangling()
kwant.plot(syst)
syst_without_lead = syst.finalized()

avg_num = 10
strength = 2
Ug = 2
energies = np.linspace(-4,4,200)
xx_list = np.zeros((int(num_cell*num_cell/2),200),dtype = complex)
xy_list = np.zeros((int(num_cell*num_cell/2),200),dtype = complex)
for num_of_up in trange(int(num_cell*num_cell/2),int(num_cell*num_cell)):
    temp_xx = 0
    temp_xy = 0
    index = num_of_up - int(num_cell*num_cell/2)
    for k in trange(avg_num,leave=False):
        up_down_array = rand_bin_array(num_of_up,num_cell)
        Mz = lambda x,y : Mz_father(x,y,up_down_array,cell_size)
        Md = np.random.uniform(-1,1,size = (W,L))
        Ma = np.random.uniform(-1,1,size = (W,L))
        Ud  = lambda x,y : U_father(x,y,strength,Md)
        Ua = lambda x,y : U_father(x,y,strength,Ma)
        params = {'vf':1,'m1':1,'m0':-0.5,'Mz':Mz,'Ua':Ua,'Ud':Ud,'Ug':Ug}
        cond_xx = kwant.kpm.conductivity(syst_without_lead, alpha = 'x',beta = 'x',params=params)
        cond_xy = kwant.kpm.conductivity(syst_without_lead, alpha = 'x',beta = 'y',params=params)
        temp_xx += np.array([cond_xx(e,temperature = 1E-6) for e in energies])
        temp_xy += np.array([cond_xy(e,temperature = 1E-6) for e in energies])
        del(cond_xx,cond_xy)
    xx_list[index,:] = temp_xx/(avg_num*W*L)
    xy_list[index,:] = temp_xy/(avg_num*W*L)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=32.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# /Users/caijiaqi/opt/anaconda3/lib/python3.7/site-packages/kwant/kpm.py:997: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp((energy - mu) / temperature))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))

# %%
num_of_up = np.arange(int(num_cell*num_cell/2),int(num_cell*num_cell))
avg_mag = (num_of_up*M_model - (num_cell*num_cell - num_of_up)*M_model)/(num_cell*num_cell)

# %%
fig,(ax1,ax2) = pyplot.subplots(1,2,figsize = (18,7))
plt = ax1.pcolor(energies,avg_mag,np.real(xx_list),cmap = 'RdBu')
plt2 = ax2.pcolor(energies,avg_mag,np.real(xy_list),cmap = 'RdBu')
ax1.set_xlabel('energy(eV)')
ax1.set_ylabel('Mz')
ax2.set_xlabel('energy(eV)')
ax2.set_ylabel('Mz')
cbar = fig.colorbar(plt,ax = ax1)
cbar = fig.colorbar(plt2,ax = ax2)

# %%
fig,ax = pyplot.subplots()
plt = ax.plot(energies,np.real(xx_list).T)

# %%
fig,ax = pyplot.subplots()
plt = ax.plot(avg_mag,np.real(xx_list))

# %%
fig,ax = pyplot.subplots()
plt = ax.plot(energies,np.real(xy_list).T)

# %%
fig,ax = pyplot.subplots()
plt = ax.plot(avg_mag,np.real(xy_list))

# %%
# gate surface dependent
template = kwant.continuum.discretize(hamiltonian,grid = a)
lat = template.lattice
def circle(site):
    x,y = site.pos
    return (x**2 + y**2 <= r**2)
def rect(site):
    x,y= site.pos
    return (0 <= y <W and 0 <=x <L)
syst = kwant.Builder()
syst.fill(template,rect,(0,0))
syst.eradicate_dangling()
kwant.plot(syst)
syst_without_lead = syst.finalized()

avg_num = 10
strength = 1
gate_list = np.linspace(-2,2,100)

xx_list = np.zeros((int(num_cell*num_cell/2),100),dtype = complex)
xy_list = np.zeros((int(num_cell*num_cell/2),100),dtype = complex)
num_of_up = np.arange(int(num_cell*num_cell/2),int(num_cell*num_cell))
avg_mag = (num_of_up*M_model - (num_cell*num_cell - num_of_up)*M_model)/(num_cell*num_cell)

for num_of_up in trange(int(num_cell*num_cell/2),int(num_cell*num_cell)):
    temp_xx = 0
    temp_xy = 0
    index = num_of_up - int(num_cell*num_cell/2)
    for k in trange(avg_num,leave=False):
        up_down_array = rand_bin_array(num_of_up,num_cell)
        Mz = lambda x,y : Mz_father(x,y,up_down_array,cell_size)
        Md = np.random.uniform(-1,1,size = (W,L))
        Ma = np.random.uniform(-1,1,size = (W,L))
        Ud  = lambda x,y : U_father(x,y,strength,Md)
        Ua = lambda x,y : U_father(x,y,strength,Ma)
        temp_xx = np.zeros((1,100),dtype = complex)
        temp_xy = np.zeros((1,100),dtype = complex)
        for (m,gate_voltage) in enumerate(gate_list):
            params = {'vf':1,'m1':1,'m0':-0.5,'Mz':Mz,'Ua':Ua,'Ud':Ud,'Ug':gate_voltage}
            cond_xx = kwant.kpm.conductivity(syst_without_lead, alpha = 'x',beta = 'x',params=params)
            cond_xy = kwant.kpm.conductivity(syst_without_lead, alpha = 'x',beta = 'y',params=params)
            temp_xx[0,m] = cond_xx(0,temperature = 1E-6)
            temp_xy[0,m] = cond_xy(0,temperature = 1E-6)
            del(cond_xx,cond_xy)
    xx_list[index,:] = temp_xx/(avg_num*W*L)
    xy_list[index,:] = temp_xy/(avg_num*W*L)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=18.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# /Users/caijiaqi/opt/anaconda3/lib/python3.7/site-packages/kwant/kpm.py:997: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp((energy - mu) / temperature))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-0e9ae77e1918> in <module>
#      38         for (m,gate_voltage) in enumerate(gate_list):
#      39             params = {'vf':1,'m1':1,'m0':-0.5,'Mz':Mz,'Ua':Ua,'Ud':Ud,'Ug':gate_voltage}
# ---> 40             cond_xx = kwant.kpm.conductivity(syst_without_lead, alpha = 'x',beta = 'x',params=params)
#      41             cond_xy = kwant.kpm.conductivity(syst_without_lead, alpha = 'x',beta = 'y',params=params)
#      42             temp_xx[0,m] = cond_xx(0,temperature = 1E-6)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/kwant/kpm.py in conductivity(hamiltonian, alpha, beta, positions, **kwargs)
#     833
#     834     correlator = Correlator(
# --> 835         hamiltonian, operator1=alpha, operator2=beta, **kwargs)
#     836
#     837     return correlator
#
# ~/opt/anaconda3/lib/python3.7/site-packages/kwant/kpm.py in __init__(self, hamiltonian, operator1, operator2, **kwargs)
#     566         # to save the vectors, accumulate_vectors must be 'True'
#     567         self._spectrum_R = SpectralDensity(hamiltonian, operator=fake_op,
# --> 568                                            **kwargs)
#     569         self._a = self._spectrum_R._a
#     570         self._b = self._spectrum_R._b
#
# ~/opt/anaconda3/lib/python3.7/site-packages/kwant/kpm.py in __init__(self, hamiltonian, params, operator, num_vectors, num_moments, energy_resolution, vector_factory, bounds, eps, rng, kernel, mean, accumulate_vectors)
#     238
#     239         self.num_moments = num_moments
# --> 240         self._update_moments_list(self.num_moments, num_vectors)
#     241
#     242         # set kernel before calling moments
#
# ~/opt/anaconda3/lib/python3.7/site-packages/kwant/kpm.py in _update_moments_list(self, n_moments, num_vectors)
#     472                 for n in range(m_start, n_moments):
#     473                     alpha_save = alpha_next
# --> 474                     alpha_next = (2 * self.hamiltonian.matvec(alpha_next)
#     475                                   - alpha)
#     476                     alpha = alpha_save
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/sparse/linalg/interface.py in matvec(self, x)
#     227             raise ValueError('dimension mismatch')
#     228
# --> 229         y = self._matvec(x)
#     230
#     231         if isinstance(x, np.matrix):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/sparse/linalg/interface.py in _matvec(self, x)
#     525
#     526     def _matvec(self, x):
# --> 527         return self.__matvec_impl(x)
#     528
#     529     def _rmatvec(self, x):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/kwant/kpm.py in rescaled(v)
#    1168
#    1169     def rescaled(v):
# -> 1170         return (hamiltonian.dot(v) - b * v) / a
#    1171
#    1172     rescaled_ham = LinearOperator(shape=hamiltonian.shape, matvec=rescaled)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/sparse/base.py in dot(self, other)
#     361
#     362         """
# --> 363         return self * other
#     364
#     365     def power(self, n, dtype=None):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/sparse/base.py in __mul__(self, other)
#     469             # Fast path for the most common case
#     470             if other.shape == (N,):
# --> 471                 return self._mul_vector(other)
#     472             elif other.shape == (N, 1):
#     473                 return self._mul_vector(other.ravel()).reshape(M, 1)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/sparse/compressed.py in _mul_vector(self, other)
#     471         # csr_matvec or csc_matvec
#     472         fn = getattr(_sparsetools, self.format + '_matvec')
# --> 473         fn(M, N, self.indptr, self.indices, self.data, other, result)
#     474
#     475         return result
#
# KeyboardInterrupt:

# %%
# fermi surface-gate voltage data dependent
# fermi surface dependent
import scipy.io as sio
from os import path

template = kwant.continuum.discretize(hamiltonian,grid = a)
lat = template.lattice
def circle(site):
    x,y = site.pos
    return (x**2 + y**2 <= r**2)
def rect(site):
    x,y= site.pos
    return (0 <= y <W and 0 <=x <L)
syst = kwant.Builder()
syst.fill(template,rect,(0,0))
syst.eradicate_dangling()
kwant.plot(syst)
syst_without_lead = syst.finalized()

avg_num = 20
strength = 1
gate_list = np.linspace(-4,4,10)

energies = np.linspace(-4,4,200)

num_of_up = np.arange(int(num_cell*num_cell/2),int(num_cell*num_cell))
avg_mag = (num_of_up*M_model - (num_cell*num_cell - num_of_up)*M_model)/(num_cell*num_cell)
count = 0
for gate in tqdm(gate_list):
    xx_list = np.zeros((int(num_cell*num_cell/2),200),dtype = complex)
    xy_list = np.zeros((int(num_cell*num_cell/2),200),dtype = complex)
    for num_of_up in trange(int(num_cell*num_cell/2),int(num_cell*num_cell),leave = False):
        temp_xx = 0
        temp_xy = 0
        index = num_of_up - int(num_cell*num_cell/2)
        for k in trange(avg_num,leave=False):
            up_down_array = rand_bin_array(num_of_up,num_cell)
            Mz = lambda x,y : Mz_father(x,y,up_down_array,cell_size)
            Md = np.random.uniform(-1,1,size = (W,L))
            Ma = np.random.uniform(-1,1,size = (W,L))
            Ud  = lambda x,y : U_father(x,y,strength,Md)
            Ua = lambda x,y : U_father(x,y,strength,Ma)
            params = {'vf':1,'m1':1,'m0':-0.5,'Mz':Mz,'Ua':Ua,'Ud':Ud,'Ug':gate}
            cond_xx = kwant.kpm.conductivity(syst_without_lead, alpha = 'x',beta = 'x',params=params)
            cond_xy = kwant.kpm.conductivity(syst_without_lead, alpha = 'x',beta = 'y',params=params)
            temp_xx += np.array([cond_xx(e,temperature = 1E-6) for e in energies])
            temp_xy += np.array([cond_xy(e,temperature = 1E-6) for e in energies])
            del(cond_xx,cond_xy)
        xx_list[index,:] = temp_xx/(avg_num*W*L)
        xy_list[index,:] = temp_xy/(avg_num*W*L)
    sio.savemat("data/da"+str(count)+".mat",{'xx':xx_list,'xy':xy_list,'E':energies,'M':avg_mag})
    count = count + 1
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=18.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# /Users/caijiaqi/opt/anaconda3/lib/python3.7/site-packages/kwant/kpm.py:997: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp((energy - mu) / temperature))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=18.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=18.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=18.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=18.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=18.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=18.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=18.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=18.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=18.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))

# %%
del(cond_xx,cond_xy)

# %%
for gate in gate_list:
    a = sio.loadmat("data\\"+str(gate)+".mat",{'xx':xx_list,'xy':xy_list,'E':energies,'M':avg_mag})
    sio.savemat("data/"+str(gate)+".mat",a)

# %%
sio.savemat("data/gatedata.mat",{"gate":gate_list})
